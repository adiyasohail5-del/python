# %% [markdown]
# The Student Class System

# %%
class Person:
    def __init__(self, name, age):
        self.name = name
        self.age = age

    def display_info(self):
        print("--Person--")
        print(f"Name: {self.name}")
        print(f"Age: {self.age}")


class Student(Person):
    def __init__(self, name, age, student_id, major):
        super().__init__(name, age,)

        self.student_id = student_id
        self.major = major

    def display_info(self):
        print("--student--")
        print(f"Name: {self.name}")
        print(f"Age: {self.age}")
        print(f"student_id: {self.student_id}")
        print(f"major: {self.major}")

class GraduateStudent(Student):
    def __init__(self, name, age, student_id, major, thesis_topic):
        super().__init__(name, age, student_id, major)
        self.thesis_topic = thesis_topic

    def display_info(self):
         def display_info(self):
          print("--Graduatestudent--")
          print(f"Name: {self.name}")
          print(f"Age: {self.age}")
          print(f"student_id: {self.student_id}")
          print(f"major: {self.major}")
          print(f"thesis topic: {self.thesis_topic}")

print("=== Enter Person Details ===")
p_name = input("Enter name: ")
p_age  = int(input("Enter age: "))          # int() converts the string to a number
person = Person(p_name, p_age)
 
print("\n=== Enter Student Details ===")
s_name  = input("Enter name: ")
s_age   = int(input("Enter age: "))
s_id    = input("Enter student ID: ")
s_major = input("Enter major: ")
student = Student(s_name, s_age, s_id, s_major)
 
print("\n=== Enter Graduate Student Details ===")
g_name   = input("Enter name: ")
g_age    = int(input("Enter age: "))
g_id     = input("Enter student ID: ")
g_major  = input("Enter major: ")
g_thesis = input("Enter thesis topic: ")
graduate = GraduateStudent(g_name, g_age, g_id, g_major, g_thesis)
 
print()
person.display_info()
print()
student.display_info()
print()
graduate.display_info()
print()
# Out:
# === Enter Person Details ===
#
# === Enter Student Details ===
#
# === Enter Graduate Student Details ===
#
# --Person--
# Name: adiya
# Age: 21
#
# --student--
# Name: adiya
# Age: 21
# student_id: 18
# major: IT
