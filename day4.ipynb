# %%
print("Hello world")
# Out:
# Hello world

# %%
x = 10
y = 20 
x + y
# Out:
# 30

# %%
a=3
b=7
print(a>b)
# Out:
# False

# %%
a=9.0
b=8.9
q=2.0
print(a,b,q)
# Out:
# 9.0 8.9 2.0

# %%
char="adiya"
print(char)
# Out:
# adiya

# %%
a=5
b=7
print(a*b)
# Out:
# 35

# %%
a=7
b=7
print(a+b)
# Out:
# 14

# %%
age=20
print(age)
# Out:
# 20

# %%
a=4
b=7
print(a<b)
# Out:
# True

# %%
print(3+7*2)
# Out:
# 17

# %%
print(10==10)
# Out:
# True

# %%
text="python"
print(text)
# Out:
# python

# %%
str1="adiya"
str2="khan"
result=str1 + " " + str2
print(result)
# Out:
# adiya khan

# %%
str1= "hy"
rsult= ((str1 + " ")* 2 + str1)
print(rsult)
# Out:
# hy hy hy

# %%
str1="samia"
print(str1[0])
# Out:
# s

# %% [markdown]
# string operations

# %%
txt= "hannan"
print(txt[0:4])
# Out:
# hann

# %%
str3= "fiyknjdk"
print(len(str3))
# Out:
# 8

# %%
str3 ="ASAD"
print(str3.lower())
# Out:
# asad

# %%
txt= "lama"
print(txt.upper())
# Out:
# LAMA

# %%
str4= "hlo"
new_str4=str4.replace("hlo" ,"by")
print(new_str4)
# Out:
# by

# %%
txt="programming is available"
substring="available"
if substring in txt:
    print("yes")
# Out:
# yes

# %% [markdown]
# list and tuples

# %%
list=[1,2,3,4,5]
print(list)
# Out:
# [1, 2, 3, 4, 5]

# %%
list=[1,2,3]
list.append(4)
print(list)
# Out:
# [1, 2, 3, 4]

# %%
list=[1,2,3]
list.remove(2)
print(list)
# Out:
# [1, 3]

# %%
str1="samia"
print(str1[0])
# Out:
# s

# %%
list=[1,2,3,4,5,6]
print(len(list))
# Out:
# 6

# %%
tuple=(2,4,6)
print(tuple)
# Out:
# (2, 4, 6)

# %%
tuple=(2,4,6)
print(tuple[0])
# Out:
# 2

# %%
list=["ali", "ahmad", "amna"]
print(list)
# Out:
# ['ali', 'ahmad', 'amna']

# %%
my_list = [10, 20, 30, 40]
my_list[1] = 99
print(my_list)
# Out:
# [10, 99, 30, 40]

# %%
name= input("enter your name")
print(" your name is " , name)
# Out:
#  your name is  hadia

# %% [markdown]
# input type casting comments
